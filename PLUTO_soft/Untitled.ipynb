# %%
import pyPLUTO as pp

# %%
d=pp.pload(0, w_dir="C:\\Users\\Susanna Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\" )
# Out:
# Reading Data file C:\Users\Susanna Parenti\Documents\LAVORO\PROJECTS\CEA\VSWMC\VSWMC_PYTHON\data.0000.dbl
# Oh BOY, something went wrong becasue 0 were not read

# %%
d.ToVTK()
# Out:
# Saving C:\Users\Susanna Parenti\Documents\LAVORO\PROJECTS\CEA\VSWMC\VSWMC_PYTHON\VTK/data.0000
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-30d12748f7c4> in <module>
# ----> 1 d.ToVTK()
#
# ~\Documents\SOFTS\PYTHON_soft\PLUTO_soft\pyPLUTO.py in ToVTK(self, outfile, additional_fields)
#    1040         x2=np.asfortranarray(self.x2r)
#    1041         x3=np.asfortranarray(self.x3r)
# -> 1042         print("Saving {}".format(outfile))
#    1043         gridToVTK(outfile,x1,x2,x3,cellData=dict_output)
#    1044
#
# ~\Anaconda3\lib\site-packages\evtk\hl.py in gridToVTK(path, x, y, z, cellData, pointData)
#     164
#     165
# --> 166     w =  VtkFile(path, ftype)
#     167     w.openGrid(start = start, end = end)
#     168     w.openPiece(start = start, end = end)
#
# ~\Anaconda3\lib\site-packages\evtk\vtk.py in __init__(self, filepath, ftype, largeFile)
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Susanna Parenti\\Documents\\SOFTS\\PYTHON_soft\\PLUTO_soft'

# %%
d.wdir
# Out:
# 'C:\\Users\\Susanna Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'

# %%
mkdir -p 'C:\\Users\\Susanna Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+"VTK"
# Out:
# Un sous-r‚pertoire ou un fichier -p existe d‚j….
# Une erreur s'est produite lors du traitement deÿ: -p.
# La syntaxe du nom de fichier, de r‚pertoire ou de volume est incorrecte.
# Une erreur s'est produite lors du traitement deÿ: 'C:\\Users\\Susanna.
# Un sous-r‚pertoire ou un fichier Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+VTK existe d‚j….
# Une erreur s'est produite lors du traitement deÿ: Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+VTK.

# %%
mkdir 'C:\\Users\\Susanna Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+"VTK"
# Out:
# La syntaxe du nom de fichier, de r‚pertoire ou de volume est incorrecte.
# Une erreur s'est produite lors du traitement deÿ: 'C:\\Users\\Susanna.
# Un sous-r‚pertoire ou un fichier Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+VTK existe d‚j….
# Une erreur s'est produite lors du traitement deÿ: Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+VTK.

# %%
pwd
# Out:
# 'C:\\Users\\Susanna Parenti\\Documents\\SOFTS\\PYTHON_soft\\PLUTO_soft'

# %%
mkdir 'C:\\Users\\Susanna\ Parenti\\Documents\\LAVORO\\PROJECTS\\CEA\\VSWMC\\VSWMC_PYTHON\\'+"VTK"
# Out:
# La syntaxe du nom de fichier, de r‚pertoire ou de volume est incorrecte.
# Une erreur s'est produite lors du traitement deÿ: 'C:\\Users\\Susanna\.
